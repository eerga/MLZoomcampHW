# %%
import pandas as pd
import numpy as np

# %%
data_url = 'cleaned_property_data.csv'
df = pd.read_csv(data_url)

# %%
numerical = ['total_num_rooms','gross_area', 'adjusted_tax', 'bed_rms', 'full_bth', 
                          'kitchens', 
                         'num_parking', 'floor_number', 
                          'building_age', 'remodel_age'] 

categorical = [
                            'land_use_description_rank',
                            'zipcode_4tier_rank',
                            'overall_condition_rank',
                            'heat_type_rank'
                         ]

# %%
for n in numerical:
    print(df[n].describe())
    print()
# Out:
# count    113931.000000
# mean          6.902827
# std           3.978395
# min           1.000000
# 25%           4.000000
# 50%           6.000000
# 75%           9.000000
# max          20.000000
# Name: total_num_rooms, dtype: float64
#
# count    113931.000000
# mean       2329.677392
# std        1724.382189
# min         130.000000
# 25%         881.000000
# 50%        1782.000000
# 75%        3467.000000
# max       14076.000000
# Name: gross_area, dtype: float64
#
# count    113931.000000
# mean       6169.088513
# std        3744.235454
# min       -2772.940000
# 25%        3433.470000
# 50%        5644.560000
# 75%        8575.220000
# max       17368.840000
# Name: adjusted_tax, dtype: float64
#
# count    113931.000000
# mean          3.132563
# std           2.072128
# min           0.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max          17.000000
# Name: bed_rms, dtype: float64
#
# count    113931.000000
# mean          1.668027
# std           0.813269
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           2.000000
# max          15.000000
# Name: full_bth, dtype: float64
#
# count    113931.000000
# mean          1.345358
# std           0.657550
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max           4.000000
# Name: kitchens, dtype: float64
#
# count    113931.000000
# mean          1.353863
# std           1.669165
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           2.000000
# max          18.000000
# Name: num_parking, dtype: float64
#
# count    113931.000000
# mean          2.747312
# std           2.886533
# min           0.000000
# 25%           2.000000
# 50%           2.000000
# 75%           3.000000
# max          59.000000
# Name: floor_number, dtype: float64
#
# count    113931.000000
# mean         92.799554
# std          69.152249
# min      -18173.000000
# 25%          65.000000
# 50%         105.000000
# 75%         125.000000
# max         325.000000
# Name: building_age, dtype: float64
#
# count    113931.000000
# mean         46.541477
# std          87.080509
# min      -18195.000000
# 25%          13.000000
# 50%          36.000000
# 75%          75.000000
# max        1824.000000
# Name: remodel_age, dtype: float64

# %%
for c in categorical:
    print(df[c].value_counts())
    print()
# Out:
# land_use_description_rank
# 1    58417
# 2    28476
# 3    15857
# 4    11181
# Name: count, dtype: int64
#
# zipcode_4tier_rank
# 3    40132
# 4    28005
# 2    25259
# 1    20535
# Name: count, dtype: int64
#
# overall_condition_rank
# 3    88515
# 4    23582
# 6      783
# 2      646
# 5      367
# 1       38
# Name: count, dtype: int64
#
# heat_type_rank
# 6    62399
# 5    42126
# 3     5465
# 4     3317
# 2      515
# 0       85
# 1       24
# Name: count, dtype: int64
